00 </td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>$94,488.59 </td><td>2119</td><td>M</td></tr><tr><td>Abdal-Khallaq,Naima</td><td>null</td><td>BPS Charlestown High</td><td>Teacher</td><td>$105,500.20 </td><td>NA</td><td>$27.50 </td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>$105,527.70 </td><td>2121</td><td>M</td></tr><tr><td>Abdelnour,Lisa</td><td>null</td><td>BPS Carter Center</td><td>Paraprofessional</td><td>$32,463.56 </td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>$32,463.56 </td><td>2131</td><td>M</td></tr><tr><td>Abdelrahim,Maha</td><td>null</td><td>Boston Public Library</td><td>Library Aide</td><td>$1,181.60 </td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>$1,181.60 </td><td>2125</td><td>M</td></tr><tr><td>Abdul-Aziz,Ramadani</td><td>null</td><td>Boston Police Department</td><td>Police Officer</td><td>$99,122.67 </td><td>NA</td><td>$800.00 </td><td>$25,411.32 </td><td> ...

# %%
# %sql

select count(_c3) as Gender_Females_AND_Males
from employees_earning
group by _c13;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Gender_Females_AND_Males</th></tr></thead><tbody><tr><td>5844</td></tr><tr><td>16202</td></tr></tbody></table></div>

# %%
# %sql

-- Task#1
--Count of Females of each profession in each department...

select _c2 as Departemnt, _c3 as profession,count(_c13) as Females
from employees_earning
where _c13 = 'F'
group by _c2,_c3;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Departemnt</th><th>profession</th><th>Females</th></tr></thead><tbody><tr><td>Cemetery Division</td><td>Grave Digger</td><td>5</td></tr><tr><td>BPS Boston Arts Academy</td><td>Community Field Coordinator</td><td>2</td></tr><tr><td>Boston Fire Department</td><td>Chemist</td><td>1</td></tr><tr><td>Elderly Commission</td><td>Dep Commissioner of Operations</td><td>1</td></tr><tr><td>Environment Department</td><td>Commissioner</td><td>1</td></tr><tr><td>Tech Boston Academy</td><td>Paraprofessional</td><td>1</td></tr><tr><td>Curley K-8</td><td>Part-Time Cafeteria Attendant</td><td>1</td></tr><tr><td>Innovation Department</td><td>Managing Partner</td><td>1</td></tr><tr><td>BPS Clap Elementary</td><td>Teacher</td><td>6</td></tr><tr><td>Public Facilities Department</td><td>Clerk of Works (PFD)</td><td>2</td></tr><tr><td>BPS Transportation</td><td>Manager (C) (non-ac)</td><td>4</td></tr><tr><td>Treasury-Collecting Division</td><td>Employment Agreement</td><td>1</td></tr><tr><td>Property Management</td><td>Admin Asst</td><td>1</td></tr><tr><td>Chief Financial Officer</td><td>Director (D) (non-ac)</td><td>1</td></tr><tr><td>BPS Condon Elementary</td><td>Paraprofessional</td><td>7</td></tr><tr><td>Boston Cntr - Youth & Families</td><td>Supv-Swimming</td><td>1</td></tr><tr><td>BPS Facility Mgmt/A & R</td><td>Manager (D) (non-ac)</td><td>1</td></tr><tr><td>BPS South Boston HS - Excel</td><td>Specialist (BTU)</td><td>1</td></tr><tr><td>BPS Mather Elementary</td><td>Prin Clerk/School Sec 19</td><td>1</td></tr><tr><td>Lyndon K-8</td><td>Prin Clerk/School Sec 19</td><td>1</td></tr><tr><td>Boston Retirement System</td><td>Student Intern</td><td>2</td></tr><tr><td>Boston Public Library</td><td>Children's Librarian I</td><td>1</td></tr><tr><td>Treasury-Collecting Division</td><td>Sr Legal Asst</td><td>1</td></tr><tr><td>BPS East Boston High</td><td>Paraprofessional</td><td>2</td></tr><tr><td>BPS Fenway High</td><td>Prin Clerk/School Sec 19</td><td>1</td></tr><tr><td>BPS Latin Academy</td><td>Part-Time Cafeteria Attendant</td><td>2</td></tr><tr><td>BPS Condon Elementary</td><td>Asst Principal Elementary</td><td>1</td></tr><tr><td>BPS Boston International HS</td><td>Guidance Counselor(1)</td><td>1</td></tr><tr><td>Treasury-Treasury Division</td><td>Supv-Accounting</td><td>3</td></tr><tr><td>Parks Department</td><td>Maint Mech (Carpenter)##</td><td>1</td></tr><tr><td>Consumer Affairs & Licensing</td><td>Staff Asst</td><td>1</td></tr><tr><td>Neighborhood Development</td><td>Housing Development Offcr</td><td>5</td></tr><tr><td>Property Management</td><td>Admin Asst I (Prop Mgnt)</td><td>1</td></tr><tr><td>Jackson/Mann K-8</td><td>Employment Agreement</td><td>2</td></tr><tr><td>Inspectional Services Dept</td><td>Prin Clerk & Typist</td><td>4</td></tr><tr><td>Boston Public Library</td><td>Library Aide</td><td>17</td></tr><tr><td>ASD Human Resources</td><td>Dep Chief Staff</td><td>1</td></tr><tr><td>Election Division</td><td>Sr Clerk</td><td>1</td></tr><tr><td>BPS Winship Elementary</td><td>Paraprofessional</td><td>1</td></tr><tr><td>Public Works Department</td><td>Maint Mech Frprs (Carpenter)##</td><td>1</td></tr><tr><td>BPS Manning Elementary</td><td>Paraprofessional</td><td>1</td></tr><tr><td>BPS Human Resource Team</td><td>Coord-Manager (D)</td><td>1</td></tr><tr><td>Haley Pilot</td><td>Principal Elementary</td><td>1</td></tr><tr><td>Boston Cntr - Youth & Families</td><td>Staff Asst</td><td>1</td></tr><tr><td>Haynes EEC</td><td>Principal Elementary</td><td>1</td></tr><tr><td>Boston Public Library</td><td>Supv of Accounting Services</td><td>1</td></tr><tr><td>Elderly Commission</td><td>Office Clerk</td><td>1</td></tr><tr><td>BPS Quincy Elementary</td><td>Paraprofessional</td><td>10</td></tr><tr><td>Property Management</td><td>Sr Admin Asst (MangrSecrtySytm</td><td>1</td></tr><tr><td>Lyon K-8</td><td>Prin Clerk/School Sec 19</td><td>1</t ...

# %%
Females = spark.sql("select _c2 as Departemnt, _c3 as profession,count(_c13) as Females\
                    from employees_earning\
                     where _c13 = 'F'\
                      group by _c2,_c3")
                   
Females.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+-------+
#           Departemnt|          profession|Females|
# +--------------------+--------------------+-------+
#    Cemetery Division|        Grave Digger|      5|
# BPS Boston Arts A...|Community Field C...|      2|
# Boston Fire Depar...|             Chemist|      1|
#   Elderly Commission|Dep Commissioner ...|      1|
# Environment Depar...|        Commissioner|      1|
#  Tech Boston Academy|    Paraprofessional|      1|
#           Curley K-8|Part-Time Cafeter...|      1|
# Innovation Depart...|    Managing Partner|      1|
#  BPS Clap Elementary|             Teacher|      6|
# Public Facilities...|Clerk of Works (PFD)|      2|
#   BPS Transportation|Manager (C) (non-ac)|      4|
# Treasury-Collecti...|Employment Agreement|      1|
#  Property Management|          Admin Asst|      1|
# Chief Financial O...|Director (D) (non...|      1|
# BPS Condon Elemen...|    Paraprofessional|      7|
# Boston Cntr - You...|       Supv-Swimming|      1|
# BPS Facility Mgmt...|Manager (D) (non-ac)|      1|
# BPS South Boston ...|    Specialist (BTU)|      1|
# BPS Mather Elemen...|Prin Clerk/School...|      1|
#           Lyndon K-8|Prin Clerk/School...|      1|
# +--------------------+--------------------+-------+
# only showing top 20 rows
#
# </div>

# %%
# %sql
-- Task#1
--Count of Males of each profession in each department...

select _c2 as Departemnt, _c3 as profession,count(_c13) as Males
from employees_earning
where _c13 = 'M'
group by _c2,_c3;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Departemnt</th><th>profession</th><th>Males</th></tr></thead><tbody><tr><td>Cemetery Division</td><td>Grave Digger</td><td>12</td></tr><tr><td>Dpt of Innovation & Technology</td><td>Data Librarian</td><td>1</td></tr><tr><td>Curley K-8</td><td>Part-Time Cafeteria Attendant</td><td>7</td></tr><tr><td>BPS Burke High</td><td>Library Paraprofessional</td><td>2</td></tr><tr><td>ASD Office Of Labor Relation</td><td>Asst Corp Counsel III</td><td>7</td></tr><tr><td>BPS Lee Elementary</td><td>Prin Clerk/School Sec 19</td><td>1</td></tr><tr><td>BPS Boston Arts Academy</td><td>Community Field Coordinator</td><td>4</td></tr><tr><td>BPS South Boston HS - Excel</td><td>Director (Basas 10B)</td><td>1</td></tr><tr><td>BPS Boston Arts Academy</td><td>Coordinator (C)</td><td>1</td></tr><tr><td>Frederick Pilot Middle</td><td>Principal Middle</td><td>1</td></tr><tr><td>Perry K-8</td><td>Lunch Hour Monitors</td><td>2</td></tr><tr><td>BPS Clap Elementary</td><td>Teacher</td><td>11</td></tr><tr><td>BPS Condon Elementary</td><td>Paraprofessional</td><td>19</td></tr><tr><td>BPS Transportation</td><td>Manager (C) (non-ac)</td><td>4</td></tr><tr><td>Public Facilities Department</td><td>Clerk of Works (PFD)</td><td>12</td></tr><tr><td>Property Management</td><td>Admin Asst</td><td>1</td></tr><tr><td>Food & Nutrition Svc</td><td>Specialist (C)</td><td>1</td></tr><tr><td>Tech Boston Academy</td><td>Chief Admin Officer</td><td>1</td></tr><tr><td>Traffic Division</td><td>Asst Traffic Sign Supv ##</td><td>1</td></tr><tr><td>Boston Police Department</td><td>Personnel Asst</td><td>1</td></tr><tr><td>BPS South Boston HS - Excel</td><td>Specialist (BTU)</td><td>1</td></tr><tr><td>Higginson/Lewis K-8</td><td>Lunch Hour Monitors</td><td>4</td></tr><tr><td>Margarita Muniz Academy</td><td>Part-Time Cafeteria Attendant</td><td>3</td></tr><tr><td>Environment Department</td><td>Receptionist/Secretary</td><td>1</td></tr><tr><td>Institutional Advancemt</td><td>Coord-Manager (B)</td><td>1</td></tr><tr><td>BPS MPH\Freshman Academy</td><td>Paraprofessional</td><td>1</td></tr><tr><td>Boston Cntr - Youth & Families</td><td>Supv-Swimming</td><td>1</td></tr><tr><td>Diplomas Plus</td><td>School Psychologist(1)</td><td>1</td></tr><tr><td>Lyndon K-8</td><td>Prin Clerk/School Sec 19</td><td>1</td></tr><tr><td>Boston Public Library</td><td>Young Adults Librarian II</td><td>2</td></tr><tr><td>Boston Retirement System</td><td>Student Intern</td><td>2</td></tr><tr><td>BPS Kenny Elementary</td><td>Lunch Hour Monitors</td><td>5</td></tr><tr><td>Boston Police Department</td><td>Dir of Human Resources (BPD)</td><td>1</td></tr><tr><td>Boston Public Library</td><td>Children's Librarian I</td><td>8</td></tr><tr><td>Boston Public Library</td><td>Curator-Professional Lib IV</td><td>3</td></tr><tr><td>Achievement Gap</td><td>Director (D) (non-ac)</td><td>1</td></tr><tr><td>Office of Arts & Culture</td><td>Project Asst</td><td>1</td></tr><tr><td>ASD Purchasing Division</td><td>Sr Admin Asst</td><td>2</td></tr><tr><td>BPS East Boston High</td><td>Paraprofessional</td><td>5</td></tr><tr><td>BPS Latin Academy</td><td>Part-Time Cafeteria Attendant</td><td>6</td></tr><tr><td>Alighieri Montessori School</td><td>Lunch Hour Monitors</td><td>2</td></tr><tr><td>BPS Condon Elementary</td><td>Asst Principal Elementary</td><td>1</td></tr><tr><td>BPS Boston Comm Leadership Ac</td><td>Specialist (BTU)</td><td>1</td></tr><tr><td>Treasury-Treasury Division</td><td>Supv-Accounting</td><td>4</td></tr><tr><td>Haynes EEC</td><td>Library Paraprofessional</td><td>1</td></tr><tr><td>Gardner Pilot  Academy</td><td>Principal Elementary</td><td>1</td></tr><tr><td>Boston Cntr - Youth & Families</td><td>Exec  Asst  (CC)</td><td>1</td></tr><tr><td>BPS O'Bryant School</td><td>Library Paraprofessional</td><td>1</td></tr><tr><td>BPS East Boston High</td><td>Sen Clerk-School Secretary 15</td><td>1</td></tr><tr><td> ...

# %%
Females = spark.sql("select _c2 as Departemnt, _c3 as profession,count(_c13) as Males\
                    from employees_earning\
                     where _c13 = 'M'\
                      group by _c2,_c3")
                   
Females.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+-----+
#           Departemnt|          profession|Males|
# +--------------------+--------------------+-----+
#    Cemetery Division|        Grave Digger|   12|
# Dpt of Innovation...|      Data Librarian|    1|
#           Curley K-8|Part-Time Cafeter...|    7|
#       BPS Burke High|Library Paraprofe...|    2|
# ASD Office Of Lab...|Asst Corp Counsel...|    7|
#   BPS Lee Elementary|Prin Clerk/School...|    1|
# BPS Boston Arts A...|Community Field C...|    4|
# BPS South Boston ...|Director (Basas 10B)|    1|
# BPS Boston Arts A...|     Coordinator (C)|    1|
# Frederick Pilot M...|    Principal Middle|    1|
#            Perry K-8| Lunch Hour Monitors|    2|
#  BPS Clap Elementary|             Teacher|   11|
# BPS Condon Elemen...|    Paraprofessional|   19|
#   BPS Transportation|Manager (C) (non-ac)|    4|
# Public Facilities...|Clerk of Works (PFD)|   12|
#  Property Management|          Admin Asst|    1|
00 </td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>$110,510.20 </td><td>2121</td><td>M</td></tr><tr><td>Abdal-Khallaq,Musiri Kari</td><td>null</td><td>Green Academy</td><td>Teacher</td><td>$93,142.59 </td><td>NA</td><td>$1,346.00 </td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>$94,488.59 </td><td>2119</td><td>M</td></tr><tr><td>Abdal-Khallaq,Naima</td><td>null</td><td>BPS Charlestown High</td><td>Teacher</td><td>$105,500.20 </td><td>NA</td><td>$27.50 </td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>$105,527.70 </td><td>2121</td><td>M</td></tr><tr><td>Abdelnour,Lisa</td><td>null</td><td>BPS Carter Center</td><td>Paraprofessional</td><td>$32,463.56 </td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>$32,463.56 </td><td>2131</td><td>M</td></tr><tr><td>Abdelrahim,Maha</td><td>null</td><td>Boston Public Library</td><td>Library Aide</td><td>$1,181.60 </td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>$1,181.60 </td><td>2125</td><td>M</td></tr><tr><td>Abdul-Aziz,Ramadani</td><td>null</td><td>Boston Police Department</td><td>Police Officer</td><td>$99,122.67 </td><td>NA</td><td>$800.00 </td><td>$25,411.32 </td><td> ...

# %%
my_schema = df.schema
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.groupBy(['_c2','_c3']).agg(F.count('_c13').alias('Gender')).limit(5)\
.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+------+
#                  _c2|                 _c3|Gender|
# +--------------------+--------------------+------+
#    Cemetery Division|        Grave Digger|    17|
# Dpt of Innovation...|      Data Librarian|     1|
#           Curley K-8|Part-Time Cafeter...|     8|
#       BPS Burke High|Library Paraprofe...|     2|
# ASD Office Of Lab...|Asst Corp Counsel...|     7|
# +--------------------+--------------------+------+
#
# </div>

# %%
#Task 1
# Count of Females of each profession in each department...
df.groupBy(['_c2','_c3','_c13']).agg(F.count('_c13').alias('Females_count'),F.col('_c13')).where(F.col('_c13')=='F').limit(5).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+----+-------------+----+
#                  _c2|                 _c3|_c13|Females_count|_c13|
# +--------------------+--------------------+----+-------------+----+
# Assessing Department|Dir-Assessing Ser...|   F|            3|   F|
# Alighieri Montess...|Lead Satellite At...|   F|            1|   F|
#     Greenwood, S K-8|Social Worker/Coo...|   F|            1|   F|
# BPS Conley Elemen...| Lunch Hour Monitors|   F|            1|   F|
#    Office of Tourism|        Project Asst|   F|            1|   F|
# +--------------------+--------------------+----+-------------+----+
#
# </div>

# %%
#Task 1
# Count of Males of each profession in each department...

df.groupBy(['_c2','_c3','_c13']).agg(F.count('_c13').alias('Males_count'),F.col('_c13')).where(F.col('_c13')=='M').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+----+-----------+----+
#                  _c2|                 _c3|_c13|Males_count|_c13|
# +--------------------+--------------------+----+-----------+----+
# Boston Cntr - You...|  Program Supervisor|   M|         23|   M|
#        Hernandez K-8|               Nurse|   M|          1|   M|
#       BPS Burke High|Library Paraprofe...|   M|          2|   M|
#   Mildred Avenue K-8|        Director (D)|   M|          1|   M|
#      BPS Horace Mann|School Psychologi...|   M|          1|   M|
# Boston Collaborat...|Employment Agreement|   M|          1|   M|
# Kennedy, PJ Eleme...|Lead Satellite At...|   M|          1|   M|
# BPS Hennigan Elem...| Swimming Instructor|   M|          1|   M|
# Public Facilities...|        Sr Admin Anl|   M|          1|   M|
# Boston Fire Depar...|Gen Frprs-Fire Al...|   M|          1|   M|
# BPS Mason Elementary|Prin Clerk/School...|   M|          1|   M|
#     Parks Department|       Staff Asst II|   M|          1|   M|
#  Student Support Svc| Project Manager (C)|   M|          3|   M|
# Youth Engagement ...|Client Informatio...|   M|          3|   M|
# Boston Cntr - You...|        Spec Asst II|   M|          3|   M|
# Fair Housing &amp; Eq...|Affirm Marketing ...|   M|          1|   M|
# BPS Manning Eleme...|Library Paraprofe...|   M|          1|   M|
#      BPS Horace Mann|    Principal Middle|   M|          2|   M|
#    BPS Irving Middle|    Principal Middle|   M|          1|   M|
# Boston Police Dep...|Video Forensic An...|   M|          1|   M|
# +--------------------+--------------------+----+-----------+----+
# only showing top 20 rows
#
# </div>

# %%
#Task 2
#Top 3 count of postal codes of each profession from each department...


df.groupBy(['_c2','_c3']).agg(F.count('_c12').alias('postal')).orderBy(F.col('postal').desc()).limit(3)\
.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------------------+------+
#                  _c2|               _c3|postal|
# +--------------------+------------------+------+
# Boston Police Dep...|    Police Officer|  1279|
# Boston Fire Depar...|      Fire Fighter|   837|
# BPS Substitute Te...|Substitute Teacher|   444|
# +--------------------+------------------+------+
#
# </div>

# %%
#Task 3
#Writing results in CSV file...
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Writing files in CSV---Task#1

Females_Total_count=df.groupBy(['_c2','_c3','_c13']).agg(F.count('_c13').alias('Females_count'),F.col('_c13')).where(F.col('_c13')=='F').limit(5)

Females_Total_count.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+----+-------------+----+
#                  _c2|                 _c3|_c13|Females_count|_c13|
# +--------------------+--------------------+----+-------------+----+
# Assessing Department|Dir-Assessing Ser...|   F|            3|   F|
# Alighieri Montess...|Lead Satellite At...|   F|            1|   F|
#     Greenwood, S K-8|Social Worker/Coo...|   F|            1|   F|
# BPS Conley Elemen...| Lunch Hour Monitors|   F|            1|   F|
#    Office of Tourism|        Project Asst|   F|            1|   F|
# +--------------------+--------------------+----+-------------+----+
#
# </div>

# %%
df.write.format("csv").save("/FileStore/tables/Females_Total_count.csv")

temp_table_name = "Females_Total_count"
df.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Writing files in CSV---Task#1

df.write.format("csv").save("/FileStore/tables/Males_Total_count.csv")

temp_table_name = "Males_Total_count"
df.createOrReplaceTempView(temp_table_name)

Males_Total_count=df.groupBy(['_c2','_c3','_c13']).agg(F.count('_c13').alias('Males_count'),F.col('_c13')).where(F.col('_c13')=='M')

Males_Total_count.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3298543768466232&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># Writing files in CSV---Task#1</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>df<span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;csv&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;/FileStore/tables/Males_Total_count.csv&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span> temp_table_name <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;Males_Total_count&#34;</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">save</span><span class="ansi-blue-fg">(self, path, format, mode, partitionBy, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1134</span>             self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1135</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 1136</span><span class="ansi-red-fg">             </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span>path<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1137</span>
# <span class="ansi-green-intense-fg ansi-bold">   1138</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1.4</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    121</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    125</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: path dbfs:/FileStore/tables/Males_Total_count.csv already exists.</div>

# %%
Males_Total_count.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+----+-----------+----+
#                  _c2|                 _c3|_c13|Males_count|_c13|
# +--------------------+--------------------+----+-----------+----+
# Boston Cntr - You...|  Program Supervisor|   M|         23|   M|
#        Hernandez K-8|               Nurse|   M|          1|   M|
#       BPS Burke High|Library Paraprofe...|   M|          2|   M|
#   Mildred Avenue K-8|        Director (D)|   M|          1|   M|
#      BPS Horace Mann|School Psychologi...|   M|          1|   M|
# Boston Collaborat...|Employment Agreement|   M|          1|   M|
# Kennedy, PJ Eleme...|Lead Satellite At...|   M|          1|   M|
# BPS Hennigan Elem...| Swimming Instructor|   M|          1|   M|
# Public Facilities...|        Sr Admin Anl|   M|          1|   M|
# Boston Fire Depar...|Gen Frprs-Fire Al...|   M|          1|   M|
# BPS Mason Elementary|Prin Clerk/School...|   M|          1|   M|
#     Parks Department|       Staff Asst II|   M|          1|   M|
#  Student Support Svc| Project Manager (C)|   M|          3|   M|
# Youth Engagement ...|Client Informatio...|   M|          3|   M|
# Boston Cntr - You...|        Spec Asst II|   M|          3|   M|
# Fair Housing &amp; Eq...|Affirm Marketing ...|   M|          1|   M|
# BPS Manning Eleme...|Library Paraprofe...|   M|          1|   M|
#      BPS Horace Mann|    Principal Middle|   M|          2|   M|
#    BPS Irving Middle|    Principal Middle|   M|          1|   M|
# Boston Police Dep...|Video Forensic An...|   M|          1|   M|
# +--------------------+--------------------+----+-----------+----+
# only showing top 20 rows
#
# </div>

# %%
df.write.format("csv").save("/FileStore/tables/postal_count.csv")

temp_table_name = "postal_count"
df.createOrReplaceTempView(temp_table_name)

postal_count =df.groupBy(['_c2','_c3']).agg(F.count('_c12').alias('postal')).orderBy(F.col('postal').desc()).limit(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
postal_count.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------------------+------+
#                  _c2|               _c3|postal|
# +--------------------+------------------+------+
# Boston Police Dep...|    Police Officer|  1279|
# Boston Fire Depar...|      Fire Fighter|   837|
# BPS Substitute Te...|Substitute Teacher|   444|
# +--------------------+------------------+------+
#
# </div>

# %%
# End of assignment...
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
